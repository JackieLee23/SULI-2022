# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dos_1 = np.loadtxt("param_1/dos.dat")
dos_2 = np.loadtxt("param_2/dos.dat")
plt.plot(dos_1[:,0], dos_1[:,1])
plt.plot(dos_2[:,0] / 2, dos_2[:,1])

# %%
dos_2 = np.loadtxt("param_2/dos.dat")
plt.plot(dos_2[:,0], dos_2[:,1])
