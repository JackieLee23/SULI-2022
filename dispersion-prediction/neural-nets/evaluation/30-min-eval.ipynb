# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
root = "/project/wyin/jlee/ml-project"
util_loc = os.path.join(root, 'utils')
sys.path.append(util_loc)
data_loc = os.path.join(root, "dispersion-prediction/data")
from utilities import ScaledData, see_results, get_model, get_prediction

# %%
model_path = os.path.join(root,
"dispersion-prediction/neural-nets/hyperparameter-search/logs/arch-search-30-min/[3, 204, 408, 612, 816, 1020, 193],0.001,512,0.5")
model = get_model(model_path)
print(model)
# Out:
# LitNeuralNet(
#   (forward_prop): Sequential(
#     (0): Linear(in_features=3, out_features=204, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=204, out_features=408, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=408, out_features=612, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=612, out_features=816, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=816, out_features=1020, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=1020, out_features=193, bias=True)
#   )
# )

# %%
data = ScaledData(data_loc, X_name = "params", y_name = "disp")
predicted = get_prediction(model, data.test_X)

# %%
percentiles = see_results(predicted, data.test_y, (10, 2), np.arange(0, 20), np.linspace(0, 3, 193), same_ylim = True)
# Out:
# model mse: 0.005786995514067626
